# %% [markdown]
# <a href="https://colab.research.google.com/github/christinezuzart/kaolin_tests/blob/master/Kaolin_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi 
# !pip install gputil 
# !pip install psutil
# !pip install humanize
import psutil 
import humanize 
import os 
import GPUtil as GPU 
GPUs = GPU.getGPUs()

# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0] 
def printm(): 
  process = psutil.Process(os.getpid())
  print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss)) 
  print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal)) 

printm()
# Out:
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp36-none-any.whl size=7410 sha256=818c47d8a71cd9ab8a5edfede23dde7345ea9696ab65135dfd67d81a7c2af327
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# ...
# Gen RAM Free: 12.8 GB  | Proc size: 156.9 MB
# GPU RAM Free: 15079MB | Used: 0MB | Util   0% | Total 15079MB

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
import torch

print(torch.__version__)
# Out:
# 1.3.1

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/kaolin_project
# Out:
# /content/gdrive/My Drive/kaolin_project

# %%
! git clone https://github.com/NVIDIAGameWorks/kaolin.git
# Out:
# fatal: destination path 'kaolin' already exists and is not an empty directory.

# %%
# %cd kaolin
# Out:
# /content/gdrive/My Drive/kaolin_project/kaolin

# %%
# !pip install pytest==4.6
# Out:
# ...
#      |████████████████████████████████| 235kB 3.4MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
# ...

# %%
# !python setup.py install
# Out:
# Building nv-usd...
# sh: 1: ./buildusd.sh: Permission denied
# running install
# running bdist_egg
# running egg_info
# writing kaolin.egg-info/PKG-INFO
# writing dependency_links to kaolin.egg-info/dependency_links.txt
# writing requirements to kaolin.egg-info/requires.txt
# writing top-level names to kaolin.egg-info/top_level.txt
# writing manifest file 'kaolin.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# running build_ext
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/kaolin
# copying build/lib.linux-x86_64-3.6/kaolin/__init__.py -> build/bdist.linux-x86_64/egg/kaolin
# copying build/lib.linux-x86_64-3.6/kaolin/helpers.py -> build/bdist.linux-x86_64/egg/kaolin
# copying build/lib.linux-x86_64-3.6/kaolin/version.py -> build/bdist.linux-x86_64/egg/kaolin
# creating build/bdist.linux-x86_64/egg/kaolin/conversions
# ...

# %%
import kaolin as kal

print(kal.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-d6a3748ddbb1> in <module>()
# ----> 1 import kaolin as kal
#       2
#       3 print(kal.__version__)
#
# /content/gdrive/My Drive/kaolin_project/kaolin/kaolin/__init__.py in <module>()
#      15 from .version import __version__
#      16
# ---> 17 from kaolin import conversions
#      18 from kaolin import datasets
#      19 from kaolin import graphics
#
# /content/gdrive/My Drive/kaolin_project/kaolin/kaolin/conversions/__init__.py in <module>()
# ----> 1 from kaolin.conversions.meshconversions import *
#       2 from kaolin.conversions.pointcloudconversions import *
#       3 from kaolin.conversions.sdfconversions import *
#       4 from kaolin.conversions.voxelgridconversions import *
#
# /content/gdrive/My Drive/kaolin_project/kaolin/kaolin/conversions/meshconversions.py in <module>()
#      20
# ...
